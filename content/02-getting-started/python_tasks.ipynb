# %% [markdown]
# <a href="https://colab.research.google.com/github/VrajMistry01/python-mastery/blob/main/content/02-getting-started/python_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def count_words(input_str):
  words_list = input_str.lower().strip().split()
  # print(words_list)
  count_dict = {}
  for word in words_list:
    if word not in count_dict:
      count_dict[word] = 1
    else:
      count_dict[word] += 1
    print(count_dict)
  return count_dict

# %%
result = count_words(" hi hi bye")
print("---")
print("returned value:", result)
print("type:", type(result))
# Out:
# {'hi': 1}
# {'hi': 2}
# {'hi': 2, 'bye': 1}
# ---
# returned value: {'hi': 2, 'bye': 1}
# type: <class 'dict'>

# %%
# 403 is thrown when the user or request is trying to access the record with is not permitted (Like student accessing school records) and 401 is thrown when unauthorized user tried to access the resource,(i.e x has skipped the login and he is trying to access the resorce which is login only)

# %%
# As for PUT, acc to my knowledge it is not.. I amy be wrong , we can put the replace the record multiple times but we have to make sure what is the latest and what is to be updated

# %%
# User has to wait, until is shows error or success once connectoion returns, It is dangerous because if the money is deducted but database entry shows failed then it may cause issue

# %%
def is_palidrom(inp_string):
  inp_list = inp_string.lower().split()
  clean_str = "".join(inp_list)
